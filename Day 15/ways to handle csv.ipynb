# %% [markdown]
# # importing pandas

# %%
import pandas as pd

# %% [markdown]
# # opening Local csv file

# %%
df = pd.read_csv('StudentPerformance.csv')

# %%
df.sample(5)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 5517              5               67                        Yes            6
# 7285              3               98                         No            9
# 5700              1               44                         No            4
# 5569              4               62                         No            4
# 3680              6               58                        Yes            6
#
#       Sample Question Papers Practiced  Performance Index
# 5517                                 1               54.0
# 7285                                 6               81.0
# 5700                                 8               18.0
# 5569                                 3               44.0
# 3680                                 8               46.0

# %% [markdown]
# # opening csv from URL

# %% [markdown]
# import requests
# from io import StringIO
# url=""
# headers = {"User-Agent": ""}
# req = requests.get(url, headers = headers)
# data = StringIO(req.text)
# od.read_csv(data)

# %% [markdown]
# # 4. seperate parameter

# %% [markdown]
# when dealing with tsv files:(tsv= tab seperated values)

# %% [markdown]
# pd.read_csv('StudentPerformance.tsv', sep = '\t')
